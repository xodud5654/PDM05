# %% [markdown]
# <a href="https://colab.research.google.com/github/xodud5654/PDM05/blob/main/py-tensorflow/DL2-CNN/dl2_07_cifar10_CNN_Daug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CNN model of cifar10 dataset**
# - Conv2D + FCN
#     * Conv2D : 2차원 합성곱 필터링 + 풀링(Pooling)
#     - > 2차원 필터로 영상을 대표하는 특징을 추출
#     * FCN : 1차원 완전연결신경망
#     - > Conv2D에서 추출된 대표 특징들을 이용하여 FCN으로 최종 학습 완료
#     * **Data augmentation**
#
# ***
# - ## Traget: **Find the best model**
# ***
#
# ![cnn_c4f5.png](https://raw.githubusercontent.com/Redwoods/Py/master//pdm2020/my-note/py-tensorflow/images/cnn_c4f5.png)

# %% [markdown]
# ## Search the best model of C4F5
# - callback
#     - Early stopping
#     - model checkpoint
# - Data augmentation

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

print(tf.__version__)
# Out:
# 2.7.0

# %%
# import TF2 submodules
from tensorflow.keras import layers, models, callbacks

# %% [markdown]
# ## **데이터 로딩, 정규화**

# %%
from keras.datasets import cifar10

(X_train0, y_train0), (X_test0, y_test0) = cifar10.load_data()

# Reshape
# X_train = X_train0.reshape(60000,28,28,1)
# X_test = X_test0.reshape(10000,28,28,1)

# Normalization
X_train, X_test = X_train0/255.0, X_test0/255.0 # 정규화

print("X_train={0}".format(X_train.shape))
print("y_train={0}".format(y_train0.shape)) 
print("X_test={0}".format(X_test.shape))
print("y_test={0}".format(y_test0.shape))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step
# X_train=(50000, 32, 32, 3)
# y_train=(50000, 1)
# X_test=(10000, 32, 32, 3)
# y_test=(10000, 1)

# %%
# One-Hot-Encoding
# Use function to_categorical() to do One-Hot-Encoding
# tf.keras.utils.to_categorical
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train0, 10)
y_test = to_categorical(y_test0, 10)
y_train.shape,y_test.shape
# Out:
# ((50000, 10), (10000, 10))

# %%
# y_train0.shape vs. y_train.shape
y_train0.shape, y_train.shape
# Out:
# ((50000, 1), (50000, 10))

# %% [markdown]
# ### Display cifar10 data
# - one random image
# - 10 representative images

# %%
# Code here!
# display one random image from the training set:
class_names =  ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

idx = np.random.randint(0, X_train0.shape[0])
print(idx)
image = X_train0[idx]
plt.imshow(image) #, cmap=plt.get_cmap('gray'))
plt.title(class_names[y_train0[idx][0]])
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# 40308

# %%
fig = plt.figure(figsize=(10,6))
num0_9 = np.unique(y_train0, return_index=True)[1]
images = X_train[num0_9]
for i in range(10):
    plt.subplot(2, 5, i+1)
    # num0_9 = X_train0[y_train0 == i]
    
    # print(num0_9.shape)
    # plt.imshow(num0_9[0]) 
    plt.imshow(images[i])
    plt.title(class_names[i])
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ## data augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
# data augmentation
# https://github.com/moritzhambach/Image-Augmentation-in-Keras-CIFAR-10-/blob/master/CNN%20with%20Image%20Augmentation%20(CIFAR10).ipynb
# set up image augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
    #zoom_range=0.3
    )
datagen.fit(X_train)

# %%
BATCH_SIZE = 50
for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=BATCH_SIZE):
    print(X_batch.shape, y_batch.shape)
    # create a grid of 5x10 images
    plt.figure(figsize=(13,13))
    for i in range(BATCH_SIZE):
        plt.subplot(5,10,i+1)
        plt.imshow(X_batch[i]) #, cmap=plt.get_cmap('gray'))
        plt.title(class_names[np.argmax(y_batch[i])])
        # show the plot
    plt.show()
    break
# Out:
# (50, 32, 32, 3) (50, 10)

# %% [markdown]
# # Design CNN

# %% [markdown]
# ### import models, layers, callbacks
# - models: Sequential
# - layers: Conv2D, MaxPool2D, Flatten
# - callbacks: ModelCheckpoint, EarlyStopping

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, TensorBoard
from keras import regularizers, optimizers

# %%
# 모델 구성
num_classes = 10
weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=X_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
 
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(128, activation='elu'))
model.add(Dense(num_classes, activation='softmax'))

# %%
opt_rms = keras.optimizers.RMSprop(learning_rate=0.001,decay=1e-6)

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_Daug_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)  # 5, 10, 20, 50

# %%
model.compile(loss='categorical_crossentropy',
        optimizer=opt_rms, # 'adam'
        metrics=['accuracy'])

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 65s 54ms/step - loss: 1.5914 - accuracy: 0.4613 - val_loss: 1.2082 - val_accuracy: 0.5961
# Epoch 2/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 1.1609 - accuracy: 0.6183 - val_loss: 1.0929 - val_accuracy: 0.6654
# Epoch 3/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 1.0410 - accuracy: 0.6656 - val_loss: 1.2214 - val_accuracy: 0.6546
# Epoch 4/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.9597 - accuracy: 0.6982 - val_loss: 0.9253 - val_accuracy: 0.7170
# Epoch 5/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.8955 - accuracy: 0.7249 - val_loss: 0.8472 - val_accuracy: 0.7542
# Epoch 6/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.8624 - accuracy: 0.7395 - val_loss: 0.8462 - val_accuracy: 0.7613
# Epoch 7/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.8280 - accuracy: 0.7552 - val_loss: 0.9343 - val_accuracy: 0.7401
# Epoch 8/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.7971 - accuracy: 0.7656 - val_loss: 0.9146 - val_accuracy: 0.7496
# Epoch 9/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.7718 - accuracy: 0.7772 - val_loss: 0.8269 - val_accuracy: 0.7653
# Epoch 10/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.7583 - accuracy: 0.7849 - val_loss: 0.6665 - val_accuracy: 0.8193
# Epoch 11/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.7387 - accuracy: 0.7916 - val_loss: 0.8316 - val_accuracy: 0.7739
# Epoch 12/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.7315 - accuracy: 0.7921 - val_loss: 0.8038 - val_accuracy: 0.7879
# Epoch 13/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.7191 - accuracy: 0.7998 - val_loss: 0.7778 - val_accuracy: 0.7997
# Epoch 14/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.7056 - accuracy: 0.8049 - val_loss: 0.7279 - val_accuracy: 0.8031
# Epoch 15/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.6949 - accuracy: 0.8090 - val_loss: 0.6862 - val_accuracy: 0.8212
# Epoch 16/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.6875 - accuracy: 0.8124 - val_loss: 0.7481 - val_accuracy: 0.8003
# Epoch 17/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6773 - accuracy: 0.8158 - val_loss: 0.6553 - val_accuracy: 0.8366
# Epoch 18/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6724 - accuracy: 0.8182 - val_loss: 0.7764 - val_accuracy: 0.7903
# Epoch 19/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.6616 - accuracy: 0.8221 - val_loss: 0.6634 - val_accuracy: 0.8256
# Epoch 20/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6613 - accuracy: 0.8247 - val_loss: 0.6716 - val_accuracy: 0.8310
# Epoch 21/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6534 - accuracy: 0.8260 - val_loss: 0.6789 - val_accuracy: 0.8240
# Epoch 22/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.6409 - accuracy: 0.8310 - val_loss: 0.6651 - val_accuracy: 0.8285
# Epoch 00022: early stopping

# %%
model.evaluate(X_test, y_test, batch_size = BATCH_SIZE)
# Out:
# 200/200 [==============================] - 3s 12ms/step - loss: 0.6651 - accuracy: 0.8285
# [0.6650940179824829, 0.828499972820282]

# %% [markdown]
# ### cifar10 Daug best Model
# - cifar10_Daug_best_weights.017-0.8366.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_Daug_best_weights.017-0.8366.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 13ms/step - loss: 0.6553 - accuracy: 0.8366
# [0.6552643179893494, 0.8366000056266785]

# %% [markdown]
# # Graph of loss and accuracy
# - model: cifar10_Daug_best

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],2)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # import models, layers, callbacks

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# # **CNN1 + FCN3**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c1f3 = tf.keras.models.Sequential([ 
    # tf.keras.layers.Flatten(input_shape=(28, 28)), 
    Conv2D(input_shape=(32,32,3), filters= 32,
            kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),  
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(128, activation='relu'),  
    tf.keras.layers.Dropout(0.25), 
    tf.keras.layers.Dense(10, activation='softmax')
])

cifar10_c1f3.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cifar10_c1f3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 256)               2097408
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 2,132,490
# Trainable params: 2,132,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c1f3_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=10)    # patience=10, 25, 50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6697 - accuracy: 0.8195 - val_loss: 0.7297 - val_accuracy: 0.8042
# Epoch 2/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6667 - accuracy: 0.8218 - val_loss: 0.7448 - val_accuracy: 0.8011
# Epoch 3/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6595 - accuracy: 0.8230 - val_loss: 0.7342 - val_accuracy: 0.8150
# Epoch 4/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6536 - accuracy: 0.8262 - val_loss: 0.6382 - val_accuracy: 0.8382
# Epoch 5/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6455 - accuracy: 0.8270 - val_loss: 0.6939 - val_accuracy: 0.8218
# Epoch 6/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6430 - accuracy: 0.8314 - val_loss: 0.6268 - val_accuracy: 0.8384
# Epoch 7/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6405 - accuracy: 0.8319 - val_loss: 0.7084 - val_accuracy: 0.8193
# Epoch 8/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.6365 - accuracy: 0.8334 - val_loss: 0.7034 - val_accuracy: 0.8210
# Epoch 9/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6252 - accuracy: 0.8362 - val_loss: 0.6046 - val_accuracy: 0.8479
# Epoch 10/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6234 - accuracy: 0.8378 - val_loss: 0.6507 - val_accuracy: 0.8345
# Epoch 11/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6226 - accuracy: 0.8399 - val_loss: 0.8673 - val_accuracy: 0.7839
# Epoch 12/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6183 - accuracy: 0.8395 - val_loss: 0.6450 - val_accuracy: 0.8380
# Epoch 13/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.6181 - accuracy: 0.8392 - val_loss: 0.5854 - val_accuracy: 0.8545
# Epoch 14/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6115 - accuracy: 0.8421 - val_loss: 0.6724 - val_accuracy: 0.8315
# Epoch 15/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6056 - accuracy: 0.8452 - val_loss: 0.6484 - val_accuracy: 0.8360
# Epoch 16/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6051 - accuracy: 0.8450 - val_loss: 0.7826 - val_accuracy: 0.8053
# Epoch 17/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6031 - accuracy: 0.8449 - val_loss: 0.6182 - val_accuracy: 0.8442
# Epoch 18/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6010 - accuracy: 0.8466 - val_loss: 0.6871 - val_accuracy: 0.8264
# Epoch 19/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5970 - accuracy: 0.8487 - val_loss: 0.6200 - val_accuracy: 0.8456
# Epoch 20/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5888 - accuracy: 0.8500 - val_loss: 0.6106 - val_accuracy: 0.8495
# Epoch 21/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5887 - accuracy: 0.8500 - val_loss: 0.6583 - val_accuracy: 0.8398
# Epoch 22/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5908 - accuracy: 0.8487 - val_loss: 0.5891 - val_accuracy: 0.8560
# Epoch 23/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5861 - accuracy: 0.8522 - val_loss: 0.5647 - val_accuracy: 0.8649
# Epoch 24/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5889 - accuracy: 0.8509 - val_loss: 0.6345 - val_accuracy: 0.8416
# Epoch 25/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5860 - accuracy: 0.8524 - val_loss: 0.6433 - val_accuracy: 0.8366
# Epoch 26/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5851 - accuracy: 0.8531 - val_loss: 0.5812 - val_accuracy: 0.8580
# Epoch 27/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5853 - accuracy: 0.8549 - val_loss: 0.6430 - val_accuracy: 0.8485
# Epoch 28/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5796 - accuracy: 0.8547 - val_loss: 0.5451 - val_accuracy: 0.8687
# Epoch 29/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5852 - accuracy: 0.8520 - val_loss: 0.7115 - val_accuracy: 0.8109
# Epoch 30/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5722 - accuracy: 0.8567 - val_loss: 0.6758 - val_accuracy: 0.8279
# Epoch 31/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5761 - accuracy: 0.8570 - val_loss: 0.5987 - val_accuracy: 0.8542
# Epoch 32/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5721 - accuracy: 0.8560 - val_loss: 0.6237 - val_accuracy: 0.8493
# Epoch 33/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5723 - accuracy: 0.8567 - val_loss: 0.5504 - val_accuracy: 0.8665
# Epoch 34/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5701 - accuracy: 0.8568 - val_loss: 0.6029 - val_accuracy: 0.8533
# Epoch 35/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5695 - accuracy: 0.8595 - val_loss: 0.6205 - val_accuracy: 0.8475
# Epoch 36/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5713 - accuracy: 0.8574 - val_loss: 0.6258 - val_accuracy: 0.8461
# Epoch 37/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5650 - accuracy: 0.8608 - val_loss: 0.5464 - val_accuracy: 0.8710
# Epoch 38/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5630 - accuracy: 0.8612 - val_loss: 0.6052 - val_accuracy: 0.8512
# Epoch 39/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5633 - accuracy: 0.8605 - val_loss: 0.6286 - val_accuracy: 0.8461
# Epoch 40/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5577 - accuracy: 0.8619 - val_loss: 0.6004 - val_accuracy: 0.8574
# Epoch 41/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5579 - accuracy: 0.8626 - val_loss: 0.6753 - val_accuracy: 0.8297
# Epoch 42/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5586 - accuracy: 0.8617 - val_loss: 0.6376 - val_accuracy: 0.8460
# Epoch 43/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.5603 - accuracy: 0.8605 - val_loss: 0.5795 - val_accuracy: 0.8629
# Epoch 44/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5573 - accuracy: 0.8625 - val_loss: 0.6161 - val_accuracy: 0.8485
# Epoch 45/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.5607 - accuracy: 0.8606 - val_loss: 0.5563 - val_accuracy: 0.8711
# Epoch 46/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5537 - accuracy: 0.8636 - val_loss: 0.5637 - val_accuracy: 0.8671
# Epoch 47/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5556 - accuracy: 0.8623 - val_loss: 0.5716 - val_accuracy: 0.8633
# Epoch 48/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5606 - accuracy: 0.8619 - val_loss: 0.5937 - val_accuracy: 0.8587
# Epoch 49/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5495 - accuracy: 0.8653 - val_loss: 0.5549 - val_accuracy: 0.8688
# Epoch 50/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5522 - accuracy: 0.8623 - val_loss: 0.5593 - val_accuracy: 0.8661
# Epoch 51/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5500 - accuracy: 0.8661 - val_loss: 0.5923 - val_accuracy: 0.8576
# Epoch 52/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5490 - accuracy: 0.8651 - val_loss: 0.5460 - val_accuracy: 0.8678
# Epoch 53/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5466 - accuracy: 0.8662 - val_loss: 0.6359 - val_accuracy: 0.8440
# Epoch 54/500
# 1000/1000 [==============================] - 56s 55ms/step - loss: 0.5486 - accuracy: 0.8638 - val_loss: 0.6072 - val_accuracy: 0.8517
# Epoch 55/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5445 - accuracy: 0.8657 - val_loss: 0.6013 - val_accuracy: 0.8547
# Epoch 00055: early stopping

# %%
cifar10_c1f3.evaluate(X_test, y_test, batch_size = 100)
# Out:
# 100/100 [==============================] - 1s 5ms/step - loss: 2.3091 - accuracy: 0.0789
# [2.3090670108795166, 0.07890000194311142]

# %% [markdown]
# # Graph of loss and accuracy
# - model: cifar_c1f3

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# 중요
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],4)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### cifar10 C1F3 Best Model
# - cifar10_c1f3_best_weights.045-0.8711.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c1f3_best_weights.045-0.8711.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 13ms/step - loss: 0.5563 - accuracy: 0.8711
# [0.5563358068466187, 0.8711000084877014]

# %% [markdown]
# ## **CNN2 + FCN2**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c2f2 = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3),kernel_size=(3,3),strides=(1,1),filters= 64,padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(kernel_size=(3,3),strides=(1,1),filters= 32,padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c2f2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cifar10_c2f2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)        1792
#
#  max_pooling2d_4 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 32)        18464
#
#  max_pooling2d_5 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_5 (Dense)             (None, 128)               262272
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 283,818
# Trainable params: 283,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
mc_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c2f2_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=10)    # patience=10, 20, 50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[mc_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 57s 56ms/step - loss: 0.5539 - accuracy: 0.8638 - val_loss: 0.6618 - val_accuracy: 0.8365
# Epoch 2/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5510 - accuracy: 0.8632 - val_loss: 0.6163 - val_accuracy: 0.8502
# Epoch 3/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5533 - accuracy: 0.8630 - val_loss: 0.6027 - val_accuracy: 0.8567
# Epoch 4/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5523 - accuracy: 0.8632 - val_loss: 0.5828 - val_accuracy: 0.8588
# Epoch 5/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5541 - accuracy: 0.8626 - val_loss: 0.5800 - val_accuracy: 0.8647
# Epoch 6/500
# 1000/1000 [==============================] - 51s 50ms/step - loss: 0.5480 - accuracy: 0.8649 - val_loss: 0.6218 - val_accuracy: 0.8553
# Epoch 7/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5469 - accuracy: 0.8663 - val_loss: 0.6164 - val_accuracy: 0.8506
# Epoch 8/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5472 - accuracy: 0.8647 - val_loss: 0.5977 - val_accuracy: 0.8559
# Epoch 9/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5432 - accuracy: 0.8676 - val_loss: 0.5653 - val_accuracy: 0.8660
# Epoch 10/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5468 - accuracy: 0.8658 - val_loss: 0.5440 - val_accuracy: 0.8704
# Epoch 11/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5430 - accuracy: 0.8679 - val_loss: 0.5926 - val_accuracy: 0.8585
# Epoch 12/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5425 - accuracy: 0.8667 - val_loss: 0.5614 - val_accuracy: 0.8650
# Epoch 13/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.5398 - accuracy: 0.8684 - val_loss: 0.5394 - val_accuracy: 0.8798
# Epoch 14/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5408 - accuracy: 0.8692 - val_loss: 0.5653 - val_accuracy: 0.8704
# Epoch 15/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5456 - accuracy: 0.8665 - val_loss: 0.5418 - val_accuracy: 0.8726
# Epoch 16/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5385 - accuracy: 0.8693 - val_loss: 0.5887 - val_accuracy: 0.8657
# Epoch 17/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5451 - accuracy: 0.8673 - val_loss: 0.6283 - val_accuracy: 0.8443
# Epoch 18/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5411 - accuracy: 0.8675 - val_loss: 0.5348 - val_accuracy: 0.8741
# Epoch 19/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.5357 - accuracy: 0.8703 - val_loss: 0.6114 - val_accuracy: 0.8561
# Epoch 20/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5360 - accuracy: 0.8701 - val_loss: 0.5621 - val_accuracy: 0.8632
# Epoch 21/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5336 - accuracy: 0.8696 - val_loss: 0.5563 - val_accuracy: 0.8724
# Epoch 22/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5396 - accuracy: 0.8695 - val_loss: 0.6418 - val_accuracy: 0.8423
# Epoch 23/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5368 - accuracy: 0.8689 - val_loss: 0.5953 - val_accuracy: 0.8598
# Epoch 00023: early stopping

# %%
cifar10_c2f2.evaluate(X_test, y_test, batch_size =100)
# Out:
# 100/100 [==============================] - 1s 6ms/step - loss: 2.3077 - accuracy: 0.1027
# [2.307710647583008, 0.10270000249147415]

# %% [markdown]
# ## Graph of loss and accuracy
# - model: cifar_c2f2

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# 중요
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],4)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c2f2_best_weights.013-0.8798.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c2f2_best_weights.013-0.8798.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 13ms/step - loss: 0.5394 - accuracy: 0.8798
# [0.5393686294555664, 0.879800021648407]

# %% [markdown]
# ## **CNN2 + FCN3**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c2f3 = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3),filters= 32, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(filters= 64, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(64, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c2f3.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cifar10_c2f3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        896
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 4096)              0
#
#  dense_7 (Dense)             (None, 128)               524416
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 552,714
# Trainable params: 552,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
mc_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c2f3_Daug_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=10)

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[mc_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 55s 54ms/step - loss: 0.5437 - accuracy: 0.8673 - val_loss: 0.6165 - val_accuracy: 0.8614
# Epoch 2/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5355 - accuracy: 0.8704 - val_loss: 0.5780 - val_accuracy: 0.8641
# Epoch 3/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5381 - accuracy: 0.8703 - val_loss: 0.5873 - val_accuracy: 0.8608
# Epoch 4/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5414 - accuracy: 0.8692 - val_loss: 0.6071 - val_accuracy: 0.8544
# Epoch 5/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5401 - accuracy: 0.8688 - val_loss: 0.6019 - val_accuracy: 0.8570
# Epoch 6/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5334 - accuracy: 0.8712 - val_loss: 0.5653 - val_accuracy: 0.8709
# Epoch 7/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5364 - accuracy: 0.8707 - val_loss: 0.5310 - val_accuracy: 0.8767
# Epoch 8/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5373 - accuracy: 0.8697 - val_loss: 0.6064 - val_accuracy: 0.8522
# Epoch 9/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5381 - accuracy: 0.8679 - val_loss: 0.5800 - val_accuracy: 0.8629
# Epoch 10/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5326 - accuracy: 0.8706 - val_loss: 0.5202 - val_accuracy: 0.8787
# Epoch 11/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5341 - accuracy: 0.8700 - val_loss: 0.6164 - val_accuracy: 0.8503
# Epoch 12/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5315 - accuracy: 0.8706 - val_loss: 0.6217 - val_accuracy: 0.8479
# Epoch 13/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5316 - accuracy: 0.8717 - val_loss: 0.6257 - val_accuracy: 0.8470
# Epoch 14/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5352 - accuracy: 0.8698 - val_loss: 0.6181 - val_accuracy: 0.8497
# Epoch 15/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.5349 - accuracy: 0.8719 - val_loss: 0.6286 - val_accuracy: 0.8541
# Epoch 16/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5308 - accuracy: 0.8714 - val_loss: 0.5375 - val_accuracy: 0.8758
# Epoch 17/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5270 - accuracy: 0.8714 - val_loss: 0.5949 - val_accuracy: 0.8630
# Epoch 18/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5307 - accuracy: 0.8721 - val_loss: 0.6022 - val_accuracy: 0.8576
# Epoch 19/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5275 - accuracy: 0.8725 - val_loss: 0.5942 - val_accuracy: 0.8590
# Epoch 20/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5288 - accuracy: 0.8715 - val_loss: 0.5679 - val_accuracy: 0.8678
# Epoch 00020: early stopping

# %%
cifar10_c2f3.evaluate(X_test, y_test, batch_size =100)
# Out:
# 100/100 [==============================] - 1s 5ms/step - loss: 2.3041 - accuracy: 0.1131
# [2.3041036128997803, 0.11309999972581863]

# %% [markdown]
# ## Graph of loss and accuracy
# - model: cifar_c2f2_Daug

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
# vacc_list[np.argmax(np.array(vacc_list))]
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],4)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c2f3_Daug_best_weights.010-0.8787.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c2f3_Daug_best_weights.010-0.8787.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 13ms/step - loss: 0.5202 - accuracy: 0.8787
# [0.5201913118362427, 0.8787000179290771]

# %% [markdown]
# ## **CNN4 + FCN5**

# %%
##여기서 부터!!! 다시
cifar10_c4f5 = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3), filters= 64, kernel_size=(3,3),strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(filters= 128, kernel_size=(3,3), strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 256, kernel_size=(3,3), strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 512, kernel_size=(3,3), strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(1024, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c4f5.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c4f5_Daug_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)    # patience=10,20,50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))                                 # 5번동안 더 높은 값이 나오지 않아서 stop
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 54s 53ms/step - loss: 0.5323 - accuracy: 0.8704 - val_loss: 0.5704 - val_accuracy: 0.8630
# Epoch 2/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5368 - accuracy: 0.8698 - val_loss: 0.6318 - val_accuracy: 0.8452
# Epoch 3/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5328 - accuracy: 0.8710 - val_loss: 0.5395 - val_accuracy: 0.8721
# Epoch 4/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5336 - accuracy: 0.8694 - val_loss: 0.5581 - val_accuracy: 0.8651
# Epoch 5/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5284 - accuracy: 0.8728 - val_loss: 0.5512 - val_accuracy: 0.8737
# Epoch 6/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5318 - accuracy: 0.8705 - val_loss: 0.5730 - val_accuracy: 0.8632
# Epoch 7/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5258 - accuracy: 0.8726 - val_loss: 0.5482 - val_accuracy: 0.8708
# Epoch 8/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5286 - accuracy: 0.8717 - val_loss: 0.5200 - val_accuracy: 0.8762
# Epoch 9/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5330 - accuracy: 0.8710 - val_loss: 0.6108 - val_accuracy: 0.8516
# Epoch 10/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5286 - accuracy: 0.8717 - val_loss: 0.6790 - val_accuracy: 0.8391
# Epoch 11/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5309 - accuracy: 0.8709 - val_loss: 0.5636 - val_accuracy: 0.8678
# Epoch 12/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5232 - accuracy: 0.8751 - val_loss: 0.5782 - val_accuracy: 0.8638
# Epoch 13/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5255 - accuracy: 0.8729 - val_loss: 0.6337 - val_accuracy: 0.8508
# Epoch 00013: early stopping

# %%
cifar10_c4f5.evaluate(X_test, y_test, batch_size = BATCH_SIZE)
# Out:
# 200/200 [==============================] - 2s 8ms/step - loss: 2.3029 - accuracy: 0.1023
# [2.3028788566589355, 0.1023000031709671]

# %% [markdown]
# # Graph of loss and accuracy
# - model: cifar10_c4f5_Daug_best_weights.008-0.8762.hdf5

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],2)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c4f5_Daug_best_weights.008-0.8762.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c4f5_Daug_best_weights.008-0.8762.hdf5')
model.evaluate(X_test, y_test, batch_size=50)
# Out:
# 200/200 [==============================] - 3s 11ms/step - loss: 0.5200 - accuracy: 0.8762
# [0.519992470741272, 0.8762000203132629]

# %% [markdown]
# # **c4f5 best model 구하기**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c4f5_ = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3),filters= 512, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(filters= 256, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 128, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 64, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(1024, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c4f5_.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c4f5_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)    # patience=10,20,50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 54s 53ms/step - loss: 0.5316 - accuracy: 0.8719 - val_loss: 0.5987 - val_accuracy: 0.8596
# Epoch 2/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5323 - accuracy: 0.8708 - val_loss: 0.4923 - val_accuracy: 0.8903
# Epoch 3/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5298 - accuracy: 0.8735 - val_loss: 0.6807 - val_accuracy: 0.8389
# Epoch 4/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5247 - accuracy: 0.8728 - val_loss: 0.5363 - val_accuracy: 0.8773
# Epoch 5/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5256 - accuracy: 0.8729 - val_loss: 0.5866 - val_accuracy: 0.8602
# Epoch 6/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5237 - accuracy: 0.8746 - val_loss: 0.5937 - val_accuracy: 0.8658
# Epoch 7/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5217 - accuracy: 0.8740 - val_loss: 0.5733 - val_accuracy: 0.8653
# Epoch 00007: early stopping

# %%
cifar10_c4f5_.evaluate(X_test, y_test, batch_size = BATCH_SIZE)
# Out:
# 200/200 [==============================] - 4s 15ms/step - loss: 2.3022 - accuracy: 0.1296
# [2.3022043704986572, 0.12960000336170197]

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],2)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c4f5_Daug_best_weights.008-0.8762.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c4f5_Daug_best_weights.008-0.8762.hdf5')
model.evaluate(X_test, y_test, batch_size=50)
# Out:
# 200/200 [==============================] - 2s 10ms/step - loss: 0.5200 - accuracy: 0.8762
# [0.519992470741272, 0.8762000203132629]

# %% [markdown]
# #** 결과 비교 **

# %%
result = [[0.6552643179893494, 0.8366000056266785], 
 [0.5090670108795166, 0.78900000194311142], 
 [0.5393686294555664, 0.879800021648407], 
[0.519992470741272, 0.8762000203132629],
 [0.49226030707359314, 0.8902999758720398]]

# %%
accuracy = [row[1] for row in result]
accuracy
# Out:
# [0.8366000056266785,
#  0.7890000019431114,
#  0.879800021648407,
#  0.8762000203132629,
#  0.8902999758720398]

# %%
x = np.arange(5)
models = ['cifar10_Daug','cifar10_c1f3','cifar10_c2f2','cifar10_c4f5_Daug','cifar_c4f5']
accuracies = [acc*100 for acc in accuracy] # %

plt.figure(figsize=(10,5))
plt.bar(x, accuracies)
plt.xticks(x, models)
plt.show()

# %% [markdown]
# ## 모형의 저장
#
# - 트레이닝이 끝난 모형은 save 메서드로 가중치와 함께 hdf5 형식으로 저장
# - load 명령으로 불러 사용

# %% [markdown]
# ### Best Daug model
# - cifar10_Daug_best_weights.013-0.8025.hdf5
# - cifar10_c4f5_Daug_best_weights.001-0.8684.hdf5
# ### Best c4f5 model of cifar10
# - cifar10_c4f5_best_weights.002-0.8903.hdf5

# %%
from keras.models import load_model

model_best = load_model('cifar10_c4f5_best_weights.002-0.8903.hdf5')
model_best.evaluate(X_test, y_test, batch_size=BATCH_SIZE)
# Out:
# 200/200 [==============================] - 2s 10ms/step - loss: 0.4923 - accuracy: 0.8903
# [0.49226030707359314, 0.8902999758720398]

# %% [markdown]
# ---

# %%
from sklearn.metrics import confusion_matrix

predictions = model_best.predict(X_test)
predictions0 = np.argmax(predictions, axis=1)
cm = confusion_matrix(y_test0, predictions0)

# %%
import seaborn as sns
plt.figure(figsize=(9,9))
sns.heatmap(cm, cbar=False, xticklabels=class_names, yticklabels=class_names, fmt='d', annot=True, cmap=plt.cm.coolwarm)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion matrix', fontsize=20)
plt.show()

# %% [markdown]
# ---
