# %% [markdown]
# <a href="https://colab.research.google.com/github/xodud5654/PDM05/blob/main/py-tensorflow/DL2-CNN/dl2_07_cifar10_CNN_Daug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CNN model of cifar10 dataset**
# - Conv2D + FCN
#     * Conv2D : 2차원 합성곱 필터링 + 풀링(Pooling)
#     - > 2차원 필터로 영상을 대표하는 특징을 추출
#     * FCN : 1차원 완전연결신경망
#     - > Conv2D에서 추출된 대표 특징들을 이용하여 FCN으로 최종 학습 완료
#     * **Data augmentation**
#
# ***
# - ## Traget: **Find the best model**
# ***
#
# ![cnn_c4f5.png](https://raw.githubusercontent.com/Redwoods/Py/master//pdm2020/my-note/py-tensorflow/images/cnn_c4f5.png)

# %% [markdown]
# ## Search the best model of C4F5
# - callback
#     - Early stopping
#     - model checkpoint
# - Data augmentation

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

print(tf.__version__)
# Out:
# 2.7.0

# %%
# import TF2 submodules
from tensorflow.keras import layers, models, callbacks

# %% [markdown]
# ## **데이터 로딩, 정규화**

# %%
from keras.datasets import cifar10

(X_train0, y_train0), (X_test0, y_test0) = cifar10.load_data()

# Reshape
# X_train = X_train0.reshape(60000,28,28,1)
# X_test = X_test0.reshape(10000,28,28,1)

# Normalization
X_train, X_test = X_train0/255.0, X_test0/255.0 # 정규화

print("X_train={0}".format(X_train.shape))
print("y_train={0}".format(y_train0.shape)) 
print("X_test={0}".format(X_test.shape))
print("y_test={0}".format(y_test0.shape))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step
# X_train=(50000, 32, 32, 3)
# y_train=(50000, 1)
# X_test=(10000, 32, 32, 3)
# y_test=(10000, 1)

# %%
# One-Hot-Encoding
# Use function to_categorical() to do One-Hot-Encoding
# tf.keras.utils.to_categorical
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train0, 10)
y_test = to_categorical(y_test0, 10)
y_train.shape,y_test.shape
# Out:
# ((50000, 10), (10000, 10))

# %%
# y_train0.shape vs. y_train.shape
y_train0.shape, y_train.shape
# Out:
# ((50000, 1), (50000, 10))

# %% [markdown]
# ### Display cifar10 data
# - one random image
# - 10 representative images

# %%
# Code here!
# display one random image from the training set:
class_names =  ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

idx = np.random.randint(0, X_train0.shape[0])
print(idx)
image = X_train0[idx]
plt.imshow(image) #, cmap=plt.get_cmap('gray'))
plt.title(class_names[y_train0[idx][0]])
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# 20983

# %%
fig = plt.figure(figsize=(10,6))
num0_9 = np.unique(y_train0, return_index=True)[1]
images = X_train[num0_9]
for i in range(10):
    plt.subplot(2, 5, i+1)
    # num0_9 = X_train0[y_train0 == i]
    
    # print(num0_9.shape)
    # plt.imshow(num0_9[0]) 
    plt.imshow(images[i])
    plt.title(class_names[i])
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ## data augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
# data augmentation
# https://github.com/moritzhambach/Image-Augmentation-in-Keras-CIFAR-10-/blob/master/CNN%20with%20Image%20Augmentation%20(CIFAR10).ipynb
# set up image augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
    #zoom_range=0.3
    )
datagen.fit(X_train)

# %%
BATCH_SIZE = 50
for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=BATCH_SIZE):
    print(X_batch.shape, y_batch.shape)
    # create a grid of 5x10 images
    plt.figure(figsize=(13,13))
    for i in range(BATCH_SIZE):
        plt.subplot(5,10,i+1)
        plt.imshow(X_batch[i]) #, cmap=plt.get_cmap('gray'))
        plt.title(class_names[np.argmax(y_batch[i])])
        # show the plot
    plt.show()
    break
# Out:
# (50, 32, 32, 3) (50, 10)

# %% [markdown]
# # Design CNN

# %% [markdown]
# ### import models, layers, callbacks
# - models: Sequential
# - layers: Conv2D, MaxPool2D, Flatten
# - callbacks: ModelCheckpoint, EarlyStopping

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, TensorBoard
from keras import regularizers, optimizers

# %%
# 모델 구성
num_classes = 10
weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=X_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
 
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(128, activation='elu'))
model.add(Dense(num_classes, activation='softmax'))

# %%
opt_rms = keras.optimizers.RMSprop(learning_rate=0.001,decay=1e-6)

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_Daug_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)  # 5, 10, 20, 50

# %%
model.compile(loss='categorical_crossentropy',
        optimizer=opt_rms, # 'adam'
        metrics=['accuracy'])

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 68s 57ms/step - loss: 1.6304 - accuracy: 0.4525 - val_loss: 1.3714 - val_accuracy: 0.5409
# Epoch 2/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 1.1834 - accuracy: 0.6076 - val_loss: 1.1632 - val_accuracy: 0.6439
# Epoch 3/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 1.0423 - accuracy: 0.6634 - val_loss: 1.0645 - val_accuracy: 0.6819
# Epoch 4/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.9713 - accuracy: 0.6956 - val_loss: 0.8938 - val_accuracy: 0.7247
# Epoch 5/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.9105 - accuracy: 0.7182 - val_loss: 1.0727 - val_accuracy: 0.6881
# Epoch 6/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.8669 - accuracy: 0.7382 - val_loss: 0.8284 - val_accuracy: 0.7604
# Epoch 7/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.8309 - accuracy: 0.7534 - val_loss: 0.8220 - val_accuracy: 0.7634
# Epoch 8/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.8101 - accuracy: 0.7613 - val_loss: 0.8541 - val_accuracy: 0.7561
# Epoch 9/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.7798 - accuracy: 0.7747 - val_loss: 0.7795 - val_accuracy: 0.7793
# Epoch 10/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.7589 - accuracy: 0.7833 - val_loss: 0.7509 - val_accuracy: 0.7950
# Epoch 11/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.7464 - accuracy: 0.7882 - val_loss: 0.8252 - val_accuracy: 0.7756
# Epoch 12/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.7309 - accuracy: 0.7940 - val_loss: 0.7042 - val_accuracy: 0.8122
# Epoch 13/500
# 1000/1000 [==============================] - 59s 59ms/step - loss: 0.7152 - accuracy: 0.8027 - val_loss: 0.8394 - val_accuracy: 0.7783
# Epoch 14/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.7087 - accuracy: 0.8037 - val_loss: 0.7307 - val_accuracy: 0.7987
# Epoch 15/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6932 - accuracy: 0.8109 - val_loss: 0.7295 - val_accuracy: 0.8002
# Epoch 16/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6897 - accuracy: 0.8118 - val_loss: 0.7103 - val_accuracy: 0.8167
# Epoch 17/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.6834 - accuracy: 0.8147 - val_loss: 0.7186 - val_accuracy: 0.8184
# Epoch 18/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.6705 - accuracy: 0.8206 - val_loss: 0.6315 - val_accuracy: 0.8388
# Epoch 19/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6613 - accuracy: 0.8221 - val_loss: 0.6115 - val_accuracy: 0.8456
# Epoch 20/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6547 - accuracy: 0.8250 - val_loss: 0.7154 - val_accuracy: 0.8183
# Epoch 21/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.6511 - accuracy: 0.8262 - val_loss: 0.6829 - val_accuracy: 0.8256
# Epoch 22/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6464 - accuracy: 0.8282 - val_loss: 0.5800 - val_accuracy: 0.8533
# Epoch 23/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6389 - accuracy: 0.8310 - val_loss: 0.7051 - val_accuracy: 0.8191
# Epoch 24/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.6342 - accuracy: 0.8331 - val_loss: 0.6072 - val_accuracy: 0.8464
# Epoch 25/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6310 - accuracy: 0.8360 - val_loss: 0.6681 - val_accuracy: 0.8301
# Epoch 26/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6296 - accuracy: 0.8361 - val_loss: 0.6829 - val_accuracy: 0.8214
# Epoch 27/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6185 - accuracy: 0.8389 - val_loss: 0.6460 - val_accuracy: 0.8379
# Epoch 00027: early stopping

# %%
model.evaluate(X_test, y_test, batch_size = BATCH_SIZE)
# Out:
# 200/200 [==============================] - 3s 12ms/step - loss: 0.6460 - accuracy: 0.8379
# [0.645989179611206, 0.8378999829292297]

# %% [markdown]
# ### cifar10 Daug best Model
# - cifar10_Daug_best_weights.022-0.8533.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_Daug_best_weights.022-0.8533.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 13ms/step - loss: 0.5800 - accuracy: 0.8533
# [0.5800009965896606, 0.8532999753952026]

# %% [markdown]
# # Graph of loss and accuracy
# - model: cifar10_Daug_best

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],2)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # import models, layers, callbacks

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# # **CNN1 + FCN3**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c1f3 = tf.keras.models.Sequential([ 
    # tf.keras.layers.Flatten(input_shape=(28, 28)), 
    Conv2D(input_shape=(32,32,3), filters= 32,
            kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),  
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(128, activation='relu'),  
    tf.keras.layers.Dropout(0.25), 
    tf.keras.layers.Dense(10, activation='softmax')
])

cifar10_c1f3.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cifar10_c1f3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 256)               2097408
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 2,132,490
# Trainable params: 2,132,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c1f3_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)    # patience=10, 25, 50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 57s 56ms/step - loss: 0.6383 - accuracy: 0.8317 - val_loss: 0.7603 - val_accuracy: 0.8089
# Epoch 2/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6310 - accuracy: 0.8344 - val_loss: 0.6207 - val_accuracy: 0.8441
# Epoch 3/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.6320 - accuracy: 0.8335 - val_loss: 0.6591 - val_accuracy: 0.8370
# Epoch 4/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.6269 - accuracy: 0.8349 - val_loss: 0.6032 - val_accuracy: 0.8473
# Epoch 5/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6222 - accuracy: 0.8374 - val_loss: 0.6709 - val_accuracy: 0.8296
# Epoch 6/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6203 - accuracy: 0.8389 - val_loss: 0.6242 - val_accuracy: 0.8431
# Epoch 7/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6113 - accuracy: 0.8414 - val_loss: 0.7965 - val_accuracy: 0.8041
# Epoch 8/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6096 - accuracy: 0.8432 - val_loss: 0.6516 - val_accuracy: 0.8332
# Epoch 9/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.6092 - accuracy: 0.8430 - val_loss: 0.5930 - val_accuracy: 0.8493
# Epoch 10/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6021 - accuracy: 0.8438 - val_loss: 0.5842 - val_accuracy: 0.8592
# Epoch 11/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.6002 - accuracy: 0.8465 - val_loss: 0.7649 - val_accuracy: 0.8094
# Epoch 12/500
# 1000/1000 [==============================] - 58s 58ms/step - loss: 0.5957 - accuracy: 0.8479 - val_loss: 0.6393 - val_accuracy: 0.8417
# Epoch 13/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5999 - accuracy: 0.8462 - val_loss: 0.5489 - val_accuracy: 0.8669
# Epoch 14/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5946 - accuracy: 0.8484 - val_loss: 0.6189 - val_accuracy: 0.8435
# Epoch 15/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5870 - accuracy: 0.8505 - val_loss: 0.5567 - val_accuracy: 0.8652
# Epoch 16/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5876 - accuracy: 0.8511 - val_loss: 0.6565 - val_accuracy: 0.8335
# Epoch 17/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.5844 - accuracy: 0.8522 - val_loss: 0.6151 - val_accuracy: 0.8465
# Epoch 18/500
# 1000/1000 [==============================] - 58s 58ms/step - loss: 0.5886 - accuracy: 0.8515 - val_loss: 0.5926 - val_accuracy: 0.8543
# Epoch 00018: early stopping

# %%
cifar10_c1f3.evaluate(X_test, y_test, batch_size = 100)
# Out:
# 100/100 [==============================] - 1s 5ms/step - loss: 2.3091 - accuracy: 0.0789
# [2.3090670108795166, 0.07890000194311142]

# %% [markdown]
# # Graph of loss and accuracy
# - model: cifar_c1f3

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# 중요
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],4)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### cifar10 C1F3 Best Model
# - cifar10_c1f3_best_weights.013-0.8669.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c1f3_best_weights.013-0.8669.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 14ms/step - loss: 0.5489 - accuracy: 0.8669
# [0.5488771796226501, 0.8669000267982483]

# %% [markdown]
# ## **CNN2 + FCN2**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c2f2 = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3),kernel_size=(3,3),strides=(1,1),filters= 64,padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(kernel_size=(3,3),strides=(1,1),filters= 32,padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c2f2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cifar10_c2f2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)        1792
#
#  max_pooling2d_4 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 32)        18464
#
#  max_pooling2d_5 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_5 (Dense)             (None, 128)               262272
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 283,818
# Trainable params: 283,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
mc_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c2f2_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=10)    # patience=10, 20, 50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[mc_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 58s 56ms/step - loss: 0.5875 - accuracy: 0.8505 - val_loss: 0.7596 - val_accuracy: 0.8066
# Epoch 2/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5903 - accuracy: 0.8496 - val_loss: 0.8144 - val_accuracy: 0.8031
# Epoch 3/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5895 - accuracy: 0.8504 - val_loss: 0.6322 - val_accuracy: 0.8447
# Epoch 4/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5878 - accuracy: 0.8504 - val_loss: 0.5485 - val_accuracy: 0.8656
# Epoch 5/500
# 1000/1000 [==============================] - 58s 58ms/step - loss: 0.5826 - accuracy: 0.8530 - val_loss: 0.6476 - val_accuracy: 0.8365
# Epoch 6/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5804 - accuracy: 0.8519 - val_loss: 0.6798 - val_accuracy: 0.8330
# Epoch 7/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5785 - accuracy: 0.8549 - val_loss: 0.6101 - val_accuracy: 0.8512
# Epoch 8/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5749 - accuracy: 0.8542 - val_loss: 0.6980 - val_accuracy: 0.8266
# Epoch 9/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5755 - accuracy: 0.8567 - val_loss: 0.5743 - val_accuracy: 0.8586
# Epoch 10/500
# 1000/1000 [==============================] - 58s 58ms/step - loss: 0.5718 - accuracy: 0.8551 - val_loss: 0.6546 - val_accuracy: 0.8372
# Epoch 11/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5709 - accuracy: 0.8561 - val_loss: 0.6151 - val_accuracy: 0.8484
# Epoch 12/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5751 - accuracy: 0.8551 - val_loss: 0.6225 - val_accuracy: 0.8487
# Epoch 13/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5713 - accuracy: 0.8567 - val_loss: 0.6263 - val_accuracy: 0.8506
# Epoch 14/500
# 1000/1000 [==============================] - 58s 58ms/step - loss: 0.5690 - accuracy: 0.8582 - val_loss: 0.6114 - val_accuracy: 0.8504
# Epoch 00014: early stopping

# %%
cifar10_c2f2.evaluate(X_test, y_test, batch_size =100)
# Out:
# 100/100 [==============================] - 1s 6ms/step - loss: 2.3077 - accuracy: 0.1027
# [2.307710647583008, 0.10270000249147415]

# %% [markdown]
# ## Graph of loss and accuracy
# - model: cifar_c2f2

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# 중요
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],4)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c2f2_best_weights.004-0.8656.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c2f2_best_weights.004-0.8656.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 13ms/step - loss: 0.5485 - accuracy: 0.8656
# [0.5485408306121826, 0.8655999898910522]

# %% [markdown]
# ## **CNN2 + FCN3**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c2f3 = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3),filters= 32, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(filters= 64, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(64, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c2f3.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cifar10_c2f3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        896
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 4096)              0
#
#  dense_7 (Dense)             (None, 128)               524416
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 552,714
# Trainable params: 552,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
mc_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c2f3_Daug_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=10)

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[mc_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 61s 59ms/step - loss: 0.5824 - accuracy: 0.8544 - val_loss: 0.6090 - val_accuracy: 0.8485
# Epoch 2/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5805 - accuracy: 0.8535 - val_loss: 0.6761 - val_accuracy: 0.8319
# Epoch 3/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5793 - accuracy: 0.8531 - val_loss: 0.5646 - val_accuracy: 0.8691
# Epoch 4/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5808 - accuracy: 0.8524 - val_loss: 0.5645 - val_accuracy: 0.8651
# Epoch 5/500
# 1000/1000 [==============================] - 58s 58ms/step - loss: 0.5777 - accuracy: 0.8526 - val_loss: 0.5838 - val_accuracy: 0.8573
# Epoch 6/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5712 - accuracy: 0.8559 - val_loss: 0.6040 - val_accuracy: 0.8520
# Epoch 7/500
# 1000/1000 [==============================] - 58s 58ms/step - loss: 0.5747 - accuracy: 0.8558 - val_loss: 0.5791 - val_accuracy: 0.8568
# Epoch 8/500
# 1000/1000 [==============================] - 58s 58ms/step - loss: 0.5700 - accuracy: 0.8573 - val_loss: 0.6003 - val_accuracy: 0.8506
# Epoch 9/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5685 - accuracy: 0.8572 - val_loss: 0.6330 - val_accuracy: 0.8400
# Epoch 10/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5698 - accuracy: 0.8571 - val_loss: 0.5874 - val_accuracy: 0.8581
# Epoch 11/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5673 - accuracy: 0.8576 - val_loss: 0.6234 - val_accuracy: 0.8452
# Epoch 12/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5645 - accuracy: 0.8595 - val_loss: 0.6482 - val_accuracy: 0.8479
# Epoch 13/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5624 - accuracy: 0.8583 - val_loss: 0.5425 - val_accuracy: 0.8727
# Epoch 14/500
# 1000/1000 [==============================] - 58s 58ms/step - loss: 0.5615 - accuracy: 0.8597 - val_loss: 0.6158 - val_accuracy: 0.8491
# Epoch 15/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5608 - accuracy: 0.8609 - val_loss: 0.5930 - val_accuracy: 0.8596
# Epoch 16/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5607 - accuracy: 0.8606 - val_loss: 0.5594 - val_accuracy: 0.8636
# Epoch 17/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5552 - accuracy: 0.8631 - val_loss: 0.6386 - val_accuracy: 0.8438
# Epoch 18/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5581 - accuracy: 0.8608 - val_loss: 0.5458 - val_accuracy: 0.8741
# Epoch 19/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5563 - accuracy: 0.8613 - val_loss: 0.5592 - val_accuracy: 0.8650
# Epoch 20/500
# 1000/1000 [==============================] - 58s 58ms/step - loss: 0.5517 - accuracy: 0.8625 - val_loss: 0.7392 - val_accuracy: 0.8167
# Epoch 21/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5519 - accuracy: 0.8619 - val_loss: 0.5676 - val_accuracy: 0.8647
# Epoch 22/500
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5546 - accuracy: 0.8634 - val_loss: 0.5786 - val_accuracy: 0.8578
# Epoch 23/500
# 1000/1000 [==============================] - 58s 58ms/step - loss: 0.5517 - accuracy: 0.8626 - val_loss: 0.5897 - val_accuracy: 0.8535
# Epoch 24/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5452 - accuracy: 0.8652 - val_loss: 0.5864 - val_accuracy: 0.8630
# Epoch 25/500
# 1000/1000 [==============================] - 58s 58ms/step - loss: 0.5460 - accuracy: 0.8655 - val_loss: 0.5490 - val_accuracy: 0.8669
# Epoch 26/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5529 - accuracy: 0.8628 - val_loss: 0.5949 - val_accuracy: 0.8612
# Epoch 27/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.5446 - accuracy: 0.8659 - val_loss: 0.6330 - val_accuracy: 0.8479
# Epoch 28/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5417 - accuracy: 0.8652 - val_loss: 0.5758 - val_accuracy: 0.8604
# Epoch 00028: early stopping

# %%
cifar10_c2f3.evaluate(X_test, y_test, batch_size =100)
# Out:
# 100/100 [==============================] - 1s 6ms/step - loss: 2.3041 - accuracy: 0.1131
# [2.3041036128997803, 0.11309999972581863]

# %% [markdown]
# ## Graph of loss and accuracy
# - model: cifar_c2f2_Daug

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
# vacc_list[np.argmax(np.array(vacc_list))]
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],4)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c2f3_Daug_best_weights.018-0.8741.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c2f3_Daug_best_weights.018-0.8741.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 13ms/step - loss: 0.5458 - accuracy: 0.8741
# [0.5457764267921448, 0.8741000294685364]

# %% [markdown]
# ## **CNN4 + FCN5**

# %%
##여기서 부터!!! 다시
cifar10_c4f5 = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3), filters= 64, kernel_size=(3,3),strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(filters= 128, kernel_size=(3,3), strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 256, kernel_size=(3,3), strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 512, kernel_size=(3,3), strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(1024, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c4f5.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c4f5_Daug_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)    # patience=10,20,50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))                                 # 5번동안 더 높은 값이 나오지 않아서 stop
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 56s 55ms/step - loss: 0.5591 - accuracy: 0.8598 - val_loss: 0.5587 - val_accuracy: 0.8684
# Epoch 2/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5590 - accuracy: 0.8604 - val_loss: 0.5959 - val_accuracy: 0.8577
# Epoch 3/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5588 - accuracy: 0.8616 - val_loss: 0.6432 - val_accuracy: 0.8451
# Epoch 4/500
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.5599 - accuracy: 0.8599 - val_loss: 0.5864 - val_accuracy: 0.8578
# Epoch 5/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5576 - accuracy: 0.8610 - val_loss: 0.6486 - val_accuracy: 0.8409
# Epoch 6/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.5571 - accuracy: 0.8620 - val_loss: 0.5682 - val_accuracy: 0.8671
# Epoch 00006: early stopping

# %%
cifar10_c4f5.evaluate(X_test, y_test, batch_size = BATCH_SIZE)
# Out:
# 200/200 [==============================] - 2s 9ms/step - loss: 2.3029 - accuracy: 0.1023
# [2.3028788566589355, 0.1023000031709671]

# %% [markdown]
# # Graph of loss and accuracy
# - model: cifar10_c4f5_Daug

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],2)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c4f5_Daug_best_weights.001-0.8684.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c4f5_Daug_best_weights.001-0.8684.hdf5')
model.evaluate(X_test, y_test, batch_size=50)
# Out:
# 200/200 [==============================] - 3s 11ms/step - loss: 0.5587 - accuracy: 0.8684
# [0.558661937713623, 0.868399977684021]

# %% [markdown]
# # **c4f5 best model 구하기**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c4f5_ = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3),filters= 512, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(filters= 256, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 128, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 64, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(1024, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c4f5_.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c4f5_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)    # patience=10,20,50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 56s 54ms/step - loss: 0.5615 - accuracy: 0.8623 - val_loss: 0.5653 - val_accuracy: 0.8671
# Epoch 2/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5628 - accuracy: 0.8599 - val_loss: 0.5809 - val_accuracy: 0.8614
# Epoch 3/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5592 - accuracy: 0.8597 - val_loss: 0.5849 - val_accuracy: 0.8594
# Epoch 4/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5598 - accuracy: 0.8620 - val_loss: 0.5894 - val_accuracy: 0.8584
# Epoch 5/500
# 1000/1000 [==============================] - 57s 57ms/step - loss: 0.5537 - accuracy: 0.8621 - val_loss: 0.6383 - val_accuracy: 0.8428
# Epoch 6/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5581 - accuracy: 0.8622 - val_loss: 0.5875 - val_accuracy: 0.8578
# Epoch 00006: early stopping

# %%
cifar10_c4f5_.evaluate(X_test, y_test, batch_size = BATCH_SIZE)
# Out:
# 200/200 [==============================] - 4s 14ms/step - loss: 2.3022 - accuracy: 0.1296
# [2.3022043704986572, 0.12960000336170197]

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],2)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c4f5_best_weights.001-0.8671.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c4f5_best_weights.001-0.8671.hdf5')
model.evaluate(X_test, y_test, batch_size=50)
# Out:
# 200/200 [==============================] - 3s 11ms/step - loss: 0.5653 - accuracy: 0.8671
# [0.5652801990509033, 0.8671000003814697]

# %% [markdown]
# #** 결과 비교 **

# %%
result = [[0.7278996109962463, 0.8025000095367432], 
 [0.6284098625183105, 0.8384000062942505], 
 [0.5490110516548157, 0.8726000189781189], 
 [0.558661937713623, 0.868399977684021],
 [0.5652801990509033, 0.8671000003814697]]

# %%
accuracy = [row[1] for row in result]
accuracy
# Out:
# [0.8025000095367432,
#  0.8384000062942505,
#  0.8726000189781189,
#  0.868399977684021,
#  0.8671000003814697]

# %%
x = np.arange(5)
models = ['cifar10_Daug','cifar10_c1f3','cifar10_c2f2','cifar10_c4f5_Daug','cifar_c4f5']
accuracies = [acc*100 for acc in accuracy] # %

plt.figure(figsize=(10,5))
plt.bar(x, accuracies)
plt.xticks(x, models)
plt.show()

# %% [markdown]
# ## 모형의 저장
#
# - 트레이닝이 끝난 모형은 save 메서드로 가중치와 함께 hdf5 형식으로 저장
# - load 명령으로 불러 사용

# %% [markdown]
# ### Best Daug model
# - cifar10_Daug_best_weights.013-0.8025.hdf5
# - cifar10_c4f5_Daug_best_weights.001-0.8684.hdf5
# ### Best c4f5 model of cifar10
# - cifar10_c4f5_best_weights.001-0.8671.hdf5

# %%
from keras.models import load_model

model_best = load_model('cifar10_c4f5_Daug_best_weights.001-0.8684.hdf5')
model_best.evaluate(X_test, y_test, batch_size=BATCH_SIZE)
# Out:
# 200/200 [==============================] - 3s 11ms/step - loss: 0.5587 - accuracy: 0.8684
# [0.558661937713623, 0.868399977684021]

# %% [markdown]
# ---

# %%
from sklearn.metrics import confusion_matrix

predictions = model_best.predict(X_test)
predictions0 = np.argmax(predictions, axis=1)
cm = confusion_matrix(y_test0, predictions0)

# %%
import seaborn as sns
plt.figure(figsize=(9,9))
sns.heatmap(cm, cbar=False, xticklabels=class_names, yticklabels=class_names, fmt='d', annot=True, cmap=plt.cm.coolwarm)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion matrix', fontsize=20)
plt.show()

# %% [markdown]
# ---
